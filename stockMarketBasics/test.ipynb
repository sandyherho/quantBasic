# %%
# Out:
# Future values of x (discrete): 127.62815625000003
# Present values of x (discrete): 78.35261664684589
# Future values of x (continuous): 128.40254166877415
# Present values of x (continuous): 77.8800783071405
